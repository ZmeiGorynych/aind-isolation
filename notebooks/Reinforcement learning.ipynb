# %%
import sys
sys.path.append('..')
import pickle

# %%
from tournament import tournament, Agent, CustomPlayerComp, improved_score_fast_x2
from data_utils import get_depths
#discount_factor = 0.99

def run_tournament(trainee_, num_rounds = 10, time_limit=float('inf'), discount_factor=0.99 ):
    result = tournament(num_rounds, test_agents = [trainee_], time_limit = time_limit)
    #print(result)
    nice_data = get_depths(result, [trainee_], lambda x:x, discount_factor)
    #print(nice_data)
    # TODO: nicer handling of final states, so wins/losses also propagate from final values via Q, not just via G
    states = [state for game in nice_data[trainee_.name] for state in game]
    print('imported',len(states), 'states')
    return states, result

# %%
mem_size = 1000000
batch_size = 10000
train_batch_size = 16
num_rounds = 10
num_init_rounds = 1000
initial_sim = False
#disc_factor = 0.99
learning_rate = 0.0001

# %%
from neural.reinforcement import Memory
memory = Memory(mem_size)
dummy_loss = 1.0 # later want to oversample high losses

# %%
if initial_sim:
    # Run this to generate the initial simulation data to pre-fit the model
    trainee = Agent(CustomPlayerComp(score_fn=improved_score_fast_x2, 
                                     name = "Trainee", 
                                     method ='alphabeta', 
                                     iterative = True), 
                    "Trainee")

    states, result = run_tournament(trainee,num_init_rounds, time_limit = 150)

    for state in states:
        memory.add((state, dummy_loss))


    with open('../data/initial_run.pickle', 'wb') as handle:
        pickle.dump(states, handle)
else:
    with open('../data/initial_run.pickle', 'rb') as handle:
        states = pickle.load(handle)

# %%
from neural.keras_utils import deep_model_fun
from neural.neural_agent import NeuralAgent
from keras.optimizers import Adam
def model_fun():
    return deep_model_fun(num_features =8, num_res_modules = 8, drop_rate = 0.1, activation = 'sigmoid')

def create_neural_agent(model_fun, name = None):
    deep_model, deep_Q_model = model_fun() 
    #deep_Q_model.load_weights(filename)#,custom_objects={'ConvByMoveLayer': ConvByMoveLayer})
    deep_model.compile(optimizer = Adam(lr=learning_rate),  loss='mean_squared_error')
    my_agent = NeuralAgent(deep_Q_model, name = name)
    return Agent(my_agent,name), deep_model, deep_Q_model
# Out:
# Using TensorFlow backend.

# %%
from tournament import tournament, Agent, RandomPlayer
my_agent, deep_model, deep_Q_model = create_neural_agent(model_fun, name = 'Trainee')

# %%
# # Option 1: load pre-calibrated states
# filename = '../data/deep_Q_model_weights.h5'
# deep_Q_model.load_weights(filename)

# %%
# # option 2: train the agent on the spot on the simulation data
# board_full, player_pos, legal_moves, next_move, target = prepare_data_for_model(states,'G')
# deep_model.fit([board_full, player_pos, legal_moves, next_move], 
#                target, 
#                batch_size = 128, 
#                epochs=1, 
#                verbose = 1, 
#                validation_split = 0.1, 
#                shuffle = True)
# deep_Q_model.save_weights('../data/deep_Q_model_weights_prefitted.h5')

# %%
i = 0

# %%
from neural.reinforcement import generate_target

while True:
    i +=1
    print('*** Iteration', i, '***')
    for state in states:
        memory.add((state, dummy_loss))
    print(len(memory.buffer))
    

    idx,batch_states = memory.sample(batch_size)
    batch_states =[b[0] for b in batch_states]

    board_full, player_pos, legal_moves, next_move, target = generate_target(batch_states, deep_Q_model, alpha=1.0, discount_factor=0.99)
    deep_model.fit([board_full, player_pos, legal_moves, next_move], 
                   target, 
                   batch_size = train_batch_size, 
                   epochs=1, 
                   verbose = 1, 
                   validation_split = 0.1, 
                   shuffle = True)
    deep_Q_model.save_weights('../data/deep_Q_model_weights_' + str(i) + '.h5')
    
    my_agent.player.temperature = 1/i
    states, result = run_tournament(my_agent,num_rounds)
# Out:
# *** Iteration 1 ***
# 295223
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0393 - val_loss: 0.0362
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 24 to 16
#   Match 2:   Trainee   vs   MM_Null   	Result: 7 to 33
#   Match 3:   Trainee   vs   MM_Open   	Result: 5 to 35
#   Match 4:   Trainee   vs MM_Improved 	Result: 5 to 35
#   Match 5:   Trainee   vs   AB_Null   	Result: 11 to 29
#   Match 6:   Trainee   vs   AB_Open   	Result: 3 to 37
#   Match 7:   Trainee   vs AB_Improved 	Result: 5 to 35
#
#
# Results:
# ----------
# Trainee             21.43%
# imported 6283 states
# *** Iteration 2 ***
# 301506
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 31s - loss: 0.0346 - val_loss: 0.0307
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 22 to 18
#   Match 2:   Trainee   vs   MM_Null   	Result: 7 to 33
#   Match 3:   Trainee   vs   MM_Open   	Result: 5 to 35
#   Match 4:   Trainee   vs MM_Improved 	Result: 7 to 33
#   Match 5:   Trainee   vs   AB_Null   	Result: 5 to 35
#   Match 6:   Trainee   vs   AB_Open   	Result: 9 to 31
#   Match 7:   Trainee   vs AB_Improved 	Result: 6 to 34
#
#
# Results:
# ----------
# Trainee             21.79%
# imported 7706 states
# *** Iteration 3 ***
# 309212
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0319 - val_loss: 0.0286
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 23 to 17
#   Match 2:   Trainee   vs   MM_Null   	Result: 8 to 32
#   Match 3:   Trainee   vs   MM_Open   	Result: 9 to 31
#   Match 4:   Trainee   vs MM_Improved 	Result: 10 to 30
#   Match 5:   Trainee   vs   AB_Null   	Result: 6 to 34
#   Match 6:   Trainee   vs   AB_Open   	Result: 5 to 35
#   Match 7:   Trainee   vs AB_Improved 	Result: 11 to 29
#
#
# Results:
# ----------
# Trainee             25.71%
# imported 9096 states
# *** Iteration 4 ***
# 318308
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 31s - loss: 0.0292 - val_loss: 0.0276
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 22 to 18
#   Match 2:   Trainee   vs   MM_Null   	Result: 5 to 35
#   Match 3:   Trainee   vs   MM_Open   	Result: 7 to 33
#   Match 4:   Trainee   vs MM_Improved 	Result: 7 to 33
#   Match 5:   Trainee   vs   AB_Null   	Result: 9 to 31
#   Match 6:   Trainee   vs   AB_Open   	Result: 10 to 30
#   Match 7:   Trainee   vs AB_Improved 	Result: 9 to 31
#
#
# Results:
# ----------
# Trainee             24.64%
# imported 10483 states
# *** Iteration 5 ***
# 328791
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0284 - val_loss: 0.0243
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 21 to 19
#   Match 2:   Trainee   vs   MM_Null   	Result: 6 to 34
#   Match 3:   Trainee   vs   MM_Open   	Result: 9 to 31
#   Match 4:   Trainee   vs MM_Improved 	Result: 3 to 37
#   Match 5:   Trainee   vs   AB_Null   	Result: 3 to 37
#   Match 6:   Trainee   vs   AB_Open   	Result: 8 to 32
#   Match 7:   Trainee   vs AB_Improved 	Result: 10 to 30
#
#
# Results:
# ----------
# Trainee             21.43%
# imported 11866 states
# *** Iteration 6 ***
# 340657
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 31s - loss: 0.0266 - val_loss: 0.0248
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 24 to 16
#   Match 2:   Trainee   vs   MM_Null   	Result: 11 to 29
#   Match 3:   Trainee   vs   MM_Open   	Result: 8 to 32
#   Match 4:   Trainee   vs MM_Improved 	Result: 7 to 33
#   Match 5:   Trainee   vs   AB_Null   	Result: 13 to 27
#   Match 6:   Trainee   vs   AB_Open   	Result: 10 to 30
#   Match 7:   Trainee   vs AB_Improved 	Result: 12 to 28
#
#
# Results:
# ----------
# Trainee             30.36%
# imported 13299 states
# *** Iteration 7 ***
# 353956
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0256 - val_loss: 0.0224
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 23 to 17
#   Match 2:   Trainee   vs   MM_Null   	Result: 9 to 31
#   Match 3:   Trainee   vs   MM_Open   	Result: 5 to 35
#   Match 4:   Trainee   vs MM_Improved 	Result: 13 to 27
#   Match 5:   Trainee   vs   AB_Null   	Result: 10 to 30
#   Match 6:   Trainee   vs   AB_Open   	Result: 12 to 28
#   Match 7:   Trainee   vs AB_Improved 	Result: 7 to 33
#
#
# Results:
# ----------
# Trainee             28.21%
# imported 14764 states
# *** Iteration 8 ***
# 368720
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0232 - val_loss: 0.0223
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 25 to 15
#   Match 2:   Trainee   vs   MM_Null   	Result: 10 to 30
#   Match 3:   Trainee   vs   MM_Open   	Result: 5 to 35
#   Match 4:   Trainee   vs MM_Improved 	Result: 9 to 31
#   Match 5:   Trainee   vs   AB_Null   	Result: 6 to 34
#   Match 6:   Trainee   vs   AB_Open   	Result: 11 to 29
#   Match 7:   Trainee   vs AB_Improved 	Result: 11 to 29
#
#
# Results:
# ----------
# Trainee             27.50%
# imported 16225 states
# *** Iteration 9 ***
# 384945
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 33s - loss: 0.0236 - val_loss: 0.0203
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 25 to 15
#   Match 2:   Trainee   vs   MM_Null   	Result: 21 to 19
#   Match 3:   Trainee   vs   MM_Open   	Result: 8 to 32
#   Match 4:   Trainee   vs MM_Improved 	Result: 11 to 29
#   Match 5:   Trainee   vs   AB_Null   	Result: 10 to 30
#   Match 6:   Trainee   vs   AB_Open   	Result: 13 to 27
#   Match 7:   Trainee   vs AB_Improved 	Result: 14 to 26
#
#
# Results:
# ----------
# Trainee             36.43%
# imported 17735 states
# *** Iteration 10 ***
# 402680
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0208 - val_loss: 0.0185
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 25 to 15
#   Match 2:   Trainee   vs   MM_Null   	Result: 10 to 30
#   Match 3:   Trainee   vs   MM_Open   	Result: 8 to 32
#   Match 4:   Trainee   vs MM_Improved 	Result: 9 to 31
#   Match 5:   Trainee   vs   AB_Null   	Result: 15 to 25
#   Match 6:   Trainee   vs   AB_Open   	Result: 12 to 28
#   Match 7:   Trainee   vs AB_Improved 	Result: 13 to 27
#
#
# Results:
# ----------
# Trainee             32.86%
# imported 19214 states
# *** Iteration 11 ***
# 421894
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0194 - val_loss: 0.0187
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 30 to 10
#   Match 2:   Trainee   vs   MM_Null   	Result: 17 to 23
#   Match 3:   Trainee   vs   MM_Open   	Result: 9 to 31
#   Match 4:   Trainee   vs MM_Improved 	Result: 13 to 27
#   Match 5:   Trainee   vs   AB_Null   	Result: 17 to 23
#   Match 6:   Trainee   vs   AB_Open   	Result: 14 to 26
#   Match 7:   Trainee   vs AB_Improved 	Result: 12 to 28
#
#
# Results:
# ----------
# Trainee             40.00%
# imported 20709 states
# *** Iteration 12 ***
# 442603
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0177 - val_loss: 0.0162
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 32 to 8
#   Match 2:   Trainee   vs   MM_Null   	Result: 15 to 25
#   Match 3:   Trainee   vs   MM_Open   	Result: 14 to 26
#   Match 4:   Trainee   vs MM_Improved 	Result: 17 to 23
#   Match 5:   Trainee   vs   AB_Null   	Result: 14 to 26
#   Match 6:   Trainee   vs   AB_Open   	Result: 14 to 26
#   Match 7:   Trainee   vs AB_Improved 	Result: 12 to 28
#
#
# Results:
# ----------
# Trainee             42.14%
# imported 22218 states
# *** Iteration 13 ***
# 464821
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0178 - val_loss: 0.0151
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 24 to 16
#   Match 2:   Trainee   vs   MM_Null   	Result: 17 to 23
#   Match 3:   Trainee   vs   MM_Open   	Result: 10 to 30
#   Match 4:   Trainee   vs MM_Improved 	Result: 15 to 25
#   Match 5:   Trainee   vs   AB_Null   	Result: 17 to 23
#   Match 6:   Trainee   vs   AB_Open   	Result: 10 to 30
#   Match 7:   Trainee   vs AB_Improved 	Result: 16 to 24
#
#
# Results:
# ----------
# Trainee             38.93%
# imported 23748 states
# *** Iteration 14 ***
# 488569
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0164 - val_loss: 0.0142
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 29 to 11
#   Match 2:   Trainee   vs   MM_Null   	Result: 18 to 22
#   Match 3:   Trainee   vs   MM_Open   	Result: 12 to 28
#   Match 4:   Trainee   vs MM_Improved 	Result: 23 to 17
#   Match 5:   Trainee   vs   AB_Null   	Result: 16 to 24
#   Match 6:   Trainee   vs   AB_Open   	Result: 14 to 26
#   Match 7:   Trainee   vs AB_Improved 	Result: 16 to 24
#
#
# Results:
# ----------
# Trainee             45.71%
# imported 25251 states
# *** Iteration 15 ***
# 513820
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0173 - val_loss: 0.0158
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 31 to 9
#   Match 2:   Trainee   vs   MM_Null   	Result: 12 to 28
#   Match 3:   Trainee   vs   MM_Open   	Result: 10 to 30
#   Match 4:   Trainee   vs MM_Improved 	Result: 14 to 26
#   Match 5:   Trainee   vs   AB_Null   	Result: 17 to 23
#   Match 6:   Trainee   vs   AB_Open   	Result: 15 to 25
#   Match 7:   Trainee   vs AB_Improved 	Result: 15 to 25
#
#
# Results:
# ----------
# Trainee             40.71%
# imported 26753 states
# *** Iteration 16 ***
# 540573
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0154 - val_loss: 0.0145
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 29 to 11
#   Match 2:   Trainee   vs   MM_Null   	Result: 12 to 28
#   Match 3:   Trainee   vs   MM_Open   	Result: 14 to 26
#   Match 4:   Trainee   vs MM_Improved 	Result: 12 to 28
#   Match 5:   Trainee   vs   AB_Null   	Result: 20 to 20
#   Match 6:   Trainee   vs   AB_Open   	Result: 16 to 24
#   Match 7:   Trainee   vs AB_Improved 	Result: 23 to 17
#
#
# Results:
# ----------
# Trainee             45.00%
# imported 28323 states
# *** Iteration 17 ***
# 568896
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 32s - loss: 0.0159 - val_loss: 0.0147
#
# *************************
#    Evaluating: Trainee
# *************************
#
# Playing Matches:
# ----------
#   Match 1:   Trainee   vs   Random    	Result: 34 to 6
#   Match 2:   Trainee   vs   MM_Null   	Result: 14 to 26
#   Match 3:   Trainee   vs   MM_Open   	Result: 11 to 29
#   Match 4:   Trainee   vs MM_Improved 	Result: 12 to 28
#   Match 5:   Trainee   vs   AB_Null   	Result: 22 to 18
#   Match 6:   Trainee   vs   AB_Open   	Result: 14 to 26
#   Match 7:   Trainee   vs AB_Improved 	Result: 11 to 29
#
#
# Results:
# ----------
# Trainee             42.14%
# imported 29828 states
# *** Iteration 18 ***
# 598724
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 7248/9000 [=======================>......] - ETA: 6s - loss: 0.0161
